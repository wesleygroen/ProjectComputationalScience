# %%
import numpy as np
import random 
import config
from collections import defaultdict
import matplotlib.pyplot as plt
from CA import *

# %%
cars, road = main_loop(0.9, 1000, 100)
print(config.flow_counter)
# Out:
# 308

# %%
plot_traffic()

# %%
cars, road = main_loop(0.9, 1000, 100, reaction_time=0)
print(config.flow_counter)
# Out:
# 338

# %%
plot_traffic()

# %%
cars, road = main_loop(0.9, 1000, 200, reaction_time=10)
plot_traffic()

# %%
main_loop(0.7, 1000, 400, reaction_time=10)
plot_traffic()

# %%
main_loop(0.4, 1000, 400, p_gen=0.4, reaction_time=10)
plot_traffic()
